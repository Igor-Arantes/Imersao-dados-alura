# %%
import pandas as pd
import matplotlib.pyplot as plt

fonte = "https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true"
fonte_dados_completos ='https://www.dropbox.com/s/kbhwy817hyzkuer/microdados_enem_2019_completo_filtrado.csv?dl=1'

dados = pd.read_csv(fonte)
dados_completos = pd.read_csv(fonte_dados_completos)

dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
dados.shape
# Out:
# (127380, 136)

# %%
dados['SG_UF_RESIDENCIA'].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
dados.columns[60:100]
# Out:
# Index(['IN_CADEIRA_ESPECIAL', 'IN_CADEIRA_CANHOTO', 'IN_CADEIRA_ACOLCHOADA',
#        'IN_PROVA_DEITADO', 'IN_MOBILIARIO_OBESO', 'IN_LAMINA_OVERLAY',
#        'IN_PROTETOR_AURICULAR', 'IN_MEDIDOR_GLICOSE', 'IN_MAQUINA_BRAILE',
#        'IN_SOROBAN', 'IN_MARCA_PASSO', 'IN_SONDA', 'IN_MEDICAMENTOS',
#        'IN_SALA_INDIVIDUAL', 'IN_SALA_ESPECIAL', 'IN_SALA_ACOMPANHANTE',
#        'IN_MOBILIARIO_ESPECIFICO', 'IN_MATERIAL_ESPECIFICO', 'IN_NOME_SOCIAL',
#        'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA',
#        'SG_UF_PROVA', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT',
#        'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC',
#        'TX_RESPOSTAS_MT', 'TP_LINGUA'],
#       dtype='object')

# %%
len(dados['SG_UF_RESIDENCIA'].unique())
# Out:
# 27

# %%
dados['SG_UF_RESIDENCIA'].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
dados['NU_IDADE'].value_counts()
# Out:
# 18    21452
# 17    21256
# 19    14418
# 20    10413
# 16     7830
#       ...
# 75        2
# 73        2
# 82        1
# 77        1
# 76        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
dados['NU_IDADE'].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %% [markdown]
# Desafio 1: Proporção de inscritos por Idade:

# %%
proporcao_idade = dados['NU_IDADE'].value_counts().sort_index()/dados['NU_IDADE'].sum()*100
proporcao_idade.sort_index()
# Out:
# 13    0.000142
# 14    0.005010
# 15    0.071383
# 16    0.278214
# 17    0.755264
#         ...
# 73    0.000071
# 75    0.000071
# 76    0.000036
# 77    0.000036
# 82    0.000036
# Name: NU_IDADE, Length: 65, dtype: float64

# %%
proporcao_idade.sort_values(ascending=False)
# Out:
# 18    0.762229
# 17    0.755264
# 19    0.512298
# 20    0.369993
# 16    0.278214
#         ...
# 73    0.000071
# 75    0.000071
# 77    0.000036
# 76    0.000036
# 82    0.000036
# Name: NU_IDADE, Length: 65, dtype: float64

# %% [markdown]
# Fim desafio 1

# %% [markdown]
# Desafio 2: Descobrir de quais estados são os inscritos com 13 anos:

# %%
dados['SG_UF_RESIDENCIA'][dados['NU_IDADE']==13]
# Out:
# 57359     SP
# 95630     MT
# 98197     AP
# 116501    BA
# Name: SG_UF_RESIDENCIA, dtype: object

# %% [markdown]
# Fim desafio 2

# %%
dados['NU_IDADE'].hist()

# %%
dados['NU_IDADE'].hist(bins=70, figsize=(12,10))

# %% [markdown]
# Desafio 3: Inserir titulo ao grafico:

# %%
plt.figure(figsize=(12,10))
plt.title('Histograma das Idades dos inscritos', fontsize=18)
dados['NU_IDADE'].hist(bins=70)
plt.show()

# %% [markdown]
# Fim desafio 3

# %%
dados.query('IN_TREINEIRO == 1')['NU_IDADE'].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %% [markdown]
# Desafio 4: Plotar os Histogramas das idades dos treineiros e não treineiros

# %%
plt.figure(figsize=(8,6))
plt.title('Histograma das Idades dos inscritos Treineiros', fontsize=14)
dados.query('IN_TREINEIRO == 1')['NU_IDADE'].hist(bins=70)
plt.figure(figsize=(8,6))
dados.query('IN_TREINEIRO == 0')['NU_IDADE'].hist(bins=70, color='g')
plt.title('Histograma das Idades dos inscritos Não Treineiros', fontsize=14)
plt.show()

# %% [markdown]
# Fim desafio 4

# %%
dados['NU_NOTA_REDACAO'].mean()
# Out:
# 571.5700253970197

# %%
dados['NU_NOTA_REDACAO'].describe()
# Out:
# count    98043.000000
# mean       571.570025
# std        188.076455
# min          0.000000
# 25%        480.000000
# 50%        580.000000
# 75%        680.000000
# max       1000.000000
# Name: NU_NOTA_REDACAO, dtype: float64

# %%
provas = ["NU_NOTA_CN","NU_NOTA_CH","NU_NOTA_MT","NU_NOTA_LC","NU_NOTA_REDACAO"]

dados[provas].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_MT    NU_NOTA_LC  NU_NOTA_REDACAO
# count  92758.000000  98043.000000  92758.000000  98043.000000     98043.000000
# mean     477.964015    507.365912    523.555206    520.463928       571.570025
# std       76.296099     82.972839    109.416939     64.556578       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    447.900000    435.300000    483.700000       480.000000
# 50%      470.200000    510.900000    501.600000    526.100000       580.000000
# 75%      533.300000    567.100000    598.200000    565.100000       680.000000
# max      797.300000    809.400000    985.000000    801.700000      1000.000000

# %%
dados["NU_NOTA_LC"].plot.box(grid = True, figsize=(8,6))

# %%
dados[provas].boxplot(grid=True, figsize= (10,8))

# %% [markdown]
# Desafio05: Comparar as distribuições das provas em inglês espanhol

# %%
plt.figure()
dados['NU_NOTA_LC'][dados['TP_LINGUA']==0].plot.box(grid = True, figsize=(8,6))
plt.title('Box Plot das provas com ligua estrangeira em ingles', fontsize=14)

plt.figure()
dados['NU_NOTA_LC'][dados['TP_LINGUA']==1].plot.box(grid = True, figsize=(8,6))
plt.title('Box Plot das provas com ligua estrangeira em espanhol', fontsize=14)

plt.show()

# %% [markdown]
# Fim desafio 5

# %%
rendas = {'A':'Nenhuma renda','B':'Até R$ 998,00','C':'De R$ 998,01 até R$ 1.497,00','D':'De R$ 1.497,01 até R$ 1.996,00','E':'De R$ 1.996,01 até R$ 2.495,00','F':'De R$ 2.495,01 até R$ 2.994,00','G':'De R$ 2.994,01 até R$ 3.992,00.','H':'De R$ 3.992,01 até R$ 4.990,00','I':'De R$ 4.990,01 até R$ 5.988,00','J':'De R$ 5.988,01 até R$ 6.986,00','K':'De R$ 6.986,01 até R$ 7.984,00','L':'De R$ 7.984,01 até R$ 8.982,00','M':'De R$ 8.982,01 até R$ 9.980,00','N':'De R$ 9.980,01 até R$ 11.976,00','O':'De R$ 11.976,01 até R$ 14.970,00','P':'De R$ 14.970,01 até R$ 19.960,00','Q':'Mais de R$ 19.960,00'}
rendas_ticks =[]
for i in rendas:
  rendas_ticks.append(rendas[i])

medias_renda = pd.DataFrame.from_dict(rendas,orient ='index')

lista_media_renda = []
for i in medias_renda.index:
  lista_media_renda.append(round(dados['NU_NOTA_CN'][dados['Q006']==i].dropna().mean(),2))
medias_renda['Media ciencias da natureza'] = lista_media_renda

lista_media_renda = []
for i in medias_renda.index:
  lista_media_renda.append(round(dados['NU_NOTA_CH'][dados['Q006']==i].dropna().mean(),2))
medias_renda['Media ciencias humanas'] = lista_media_renda

lista_media_renda = []
for i in medias_renda.index:
  lista_media_renda.append(round(dados['NU_NOTA_LC'][dados['Q006']==i].dropna().mean(),2))
medias_renda['Media liguagens e codigos'] = lista_media_renda

lista_media_renda = []
for i in medias_renda.index:
  lista_media_renda.append(round(dados['NU_NOTA_MT'][dados['Q006']==i].dropna().mean(),2))
medias_renda['Media matematica'] = lista_media_renda

lista_media_renda = []
for i in medias_renda.index:
  lista_media_renda.append(round(dados['NU_NOTA_REDACAO'][dados['Q006']==i].dropna().mean(),2))
medias_renda['Media redacao'] = lista_media_renda

medias_renda['Media Geral'] = (medias_renda['Media redacao']+medias_renda['Media matematica']+medias_renda['Media liguagens e codigos']+medias_renda['Media ciencias humanas']+medias_renda['Media ciencias da natureza'])/5

medias_renda.rename(columns={0:'Renda'})
# Out:
#                               Renda  ...  Media Geral
# A                     Nenhuma renda  ...      472.036
# B                     Até R$ 998,00  ...      480.304
# C      De R$ 998,01 até R$ 1.497,00  ...      500.844
# D    De R$ 1.497,01 até R$ 1.996,00  ...      519.080
# E    De R$ 1.996,01 até R$ 2.495,00  ...      527.918
# F    De R$ 2.495,01 até R$ 2.994,00  ...      545.080
# G   De R$ 2.994,01 até R$ 3.992,00.  ...      552.076
# H    De R$ 3.992,01 até R$ 4.990,00  ...      571.550
# I    De R$ 4.990,01 até R$ 5.988,00  ...      577.778
# J    De R$ 5.988,01 até R$ 6.986,00  ...      585.282
# K    De R$ 6.986,01 até R$ 7.984,00  ...      596.668
# L    De R$ 7.984,01 até R$ 8.982,00  ...      606.236
# M    De R$ 8.982,01 até R$ 9.980,00  ...      601.064
# N   De R$ 9.980,01 até R$ 11.976,00  ...      611.730
# O  De R$ 11.976,01 até R$ 14.970,00  ...      618.312
# P  De R$ 14.970,01 até R$ 19.960,00  ...      631.328
# Q              Mais de R$ 19.960,00  ...      637.028
#
# [17 rows x 7 columns]

# %%
fig = plt.figure(figsize=(16,12))
axis = fig.add_axes([0,0,1,1])


plt.title('Nota  media por renda familiar', fontsize=14)
media_geral = medias_renda['Media Geral']
index=range(len(rendas_ticks))

axis.grid(True)
axis.bar(index,media_geral, color='orange')

axis.set_yticks([100,200,300,400,450,500,550,600,650,700,750,800])
axis.set_xticks(index)
axis.set_xticklabels(rendas_ticks)
plt.xticks(rotation=60)

axis.axhline(max(medias_renda['Media Geral']),color='k',linestyle='--')
axis.axhline(min(medias_renda['Media Geral']),color='k',linestyle='--')


plt.show()

# %% [markdown]
# Fim desafio 6

# %% [markdown]
# #Aula 2

# %%
#Resolvendo o desafio 1 com apenas uma linha de codigo

dados['NU_IDADE'].value_counts(normalize=True)
# Out:
# 18    0.168409
# 17    0.166871
# 19    0.113189
# 20    0.081748
# 16    0.061470
#         ...
# 75    0.000016
# 73    0.000016
# 82    0.000008
# 77    0.000008
# 76    0.000008
# Name: NU_IDADE, Length: 65, dtype: float64

# %%
alunos_menor_quatorze = dados.query('NU_IDADE <= 14')
alunos_menor_quatorze['SG_UF_RESIDENCIA'].value_counts().plot.pie(figsize=(12,10))
plt.show()

# %%
alunos_menor_quatorze = dados.query('NU_IDADE <= 14')
alunos_menor_quatorze['SG_UF_RESIDENCIA'].value_counts().plot.bar(figsize=(12,10))
plt.show()

# %% [markdown]
# Mega desafio da Thainá: Pegar a amostra dos alunos de 13 e 14  anos. ( Usando a base completa)

# %%
alunos_menor_quatorze = dados_completos.query('NU_IDADE <= 14')
alunos_menor_quatorze['SG_UF_RESIDENCIA'].value_counts().plot.bar(figsize=(12,10))
plt.show()

# %%
rendas = {'A':'Nenhuma renda','B':'Até R$ 998,00','C':'De R$ 998,01 até R$ 1.497,00','D':'De R$ 1.497,01 até R$ 1.996,00','E':'De R$ 1.996,01 até R$ 2.495,00','F':'De R$ 2.495,01 até R$ 2.994,00','G':'De R$ 2.994,01 até R$ 3.992,00.','H':'De R$ 3.992,01 até R$ 4.990,00','I':'De R$ 4.990,01 até R$ 5.988,00','J':'De R$ 5.988,01 até R$ 6.986,00','K':'De R$ 6.986,01 até R$ 7.984,00','L':'De R$ 7.984,01 até R$ 8.982,00','M':'De R$ 8.982,01 até R$ 9.980,00','N':'De R$ 9.980,01 até R$ 11.976,00','O':'De R$ 11.976,01 até R$ 14.970,00','P':'De R$ 14.970,01 até R$ 19.960,00','Q':'Mais de R$ 19.960,00'}
rendas_ticks =[]
for i in rendas:
  rendas_ticks.append(rendas[i])

medias_renda = pd.DataFrame.from_dict(rendas,orient ='index')

lista_media_renda = []
for i in medias_renda.index:
  lista_media_renda.append(round(dados_completos['NU_NOTA_CN'][dados_completos['Q006']==i].dropna().mean(),2))
medias_renda['Media ciencias da natureza'] = lista_media_renda

lista_media_renda = []
for i in medias_renda.index:
  lista_media_renda.append(round(dados_completos['NU_NOTA_CH'][dados_completos['Q006']==i].dropna().mean(),2))
medias_renda['Media ciencias humanas'] = lista_media_renda

lista_media_renda = []
for i in medias_renda.index:
  lista_media_renda.append(round(dados_completos['NU_NOTA_LC'][dados_completos['Q006']==i].dropna().mean(),2))
medias_renda['Media liguagens e codigos'] = lista_media_renda

lista_media_renda = []
for i in medias_renda.index:
  lista_media_renda.append(round(dados_completos['NU_NOTA_MT'][dados_completos['Q006']==i].dropna().mean(),2))
medias_renda['Media matematica'] = lista_media_renda

lista_media_renda = []
for i in medias_renda.index:
  lista_media_renda.append(round(dados_completos['NU_NOTA_REDACAO'][dados_completos['Q006']==i].dropna().mean(),2))
medias_renda['Media redacao'] = lista_media_renda

medias_renda['Media Geral'] = (medias_renda['Media redacao']+medias_renda['Media matematica']+medias_renda['Media liguagens e codigos']+medias_renda['Media ciencias humanas']+medias_renda['Media ciencias da natureza'])/5

medias_renda.rename(columns={0:'Renda'})

fig = plt.figure(figsize=(16,12))
axis = fig.add_axes([0,0,1,1])


plt.title('Nota  media por renda familiar', fontsize=14)
media_geral = medias_renda['Media Geral']
index=range(len(rendas_ticks))

axis.grid(True)
axis.bar(index,media_geral, color='orange')

axis.set_yticks([100,200,300,400,450,500,550,600,650,700,750,800])
axis.set_xticks(index)
axis.set_xticklabels(rendas_ticks)
plt.xticks(rotation=60)

axis.axhline(max(medias_renda['Media Geral']),color='k',linestyle='--')
axis.axhline(min(medias_renda['Media Geral']),color='k',linestyle='--')



plt.show()

# %% [markdown]
# Desafio do Gui bonzinho: aumentar a amosta para alunos menores de idade e a proporção por estado

# %%
alunos_menores_idade = dados.query('NU_IDADE < 18')
alunos_menores_idade['SG_UF_RESIDENCIA'].value_counts(normalize=True).plot.bar(grid=True,figsize=(12,10),color='k')
plt.show()

# %% [markdown]
# Fim Desafio Gui bonzinho

# %%
import seaborn as sns

# %%
renda_ordenada = dados["Q006"].unique()
renda_ordenada.sort()
plt.figure(figsize=(12,10))
plt.title("Boxplot Notas Matematica por faixa de renda")
sns.boxplot(x="Q006", y="NU_NOTA_MT", data=dados, order=renda_ordenada)
plt.show()

# %%
dados['NU_NOTA_TOTAL'] = dados[provas].sum(axis=1)

# %%
renda_ordenada = dados["Q006"].unique()
renda_ordenada.sort()
plt.figure(figsize=(12,10))
plt.title("Boxplot Notas Matematica por faixa de renda")
sns.boxplot(x="Q006", y='NU_NOTA_TOTAL', data=dados, order=renda_ordenada)
plt.show()

# %% [markdown]
# Desafio 6: Criar uma função para plotar o  box plot
# (desafio 3 do dia 2)

# %%
def box_plot_padrao(x, y , data,hue):
  x_ordenada = dados[x].unique()
  x_ordenada.sort()
  plt.figure(figsize=(12,10))
  plt.title("Boxplot "+ y+" por "+x)
  sns.boxplot(x=x, y=y, data=data, order=x_ordenada,hue=hue)
  plt.show()

# %% [markdown]
# Fim do desafio 6

# %%
sns.displot(dados, x='NU_NOTA_TOTAL')

# %%
provas = ["NU_NOTA_CN","NU_NOTA_CH","NU_NOTA_MT","NU_NOTA_LC","NU_NOTA_REDACAO"]
provas.append('NU_NOTA_TOTAL')
dados[provas].query('NU_NOTA_TOTAL ==0')
# Out:
#         NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# 10             NaN         NaN  ...              NaN            0.0
# 11             NaN         NaN  ...              NaN            0.0
# 26             NaN         NaN  ...              NaN            0.0
# 38             NaN         NaN  ...              NaN            0.0
# 40             NaN         NaN  ...              NaN            0.0
# ...            ...         ...  ...              ...            ...
# 127351         NaN         NaN  ...              NaN            0.0
# 127365         NaN         NaN  ...              NaN            0.0
# 127366         NaN         NaN  ...              NaN            0.0
# 127368         NaN         NaN  ...              NaN            0.0
# 127374         NaN         NaN  ...              NaN            0.0
#
# [29162 rows x 6 columns]

# %% [markdown]
# Desafio 7: Verificar se quem zerou a prova foi eliminado ou ausente
# (Desafio 4 do dia 2)

# %%
presenca = ["TP_PRESENCA_CN","TP_PRESENCA_CH","TP_PRESENCA_MT","TP_PRESENCA_LC"]
dados['TP_PRESENCA_TT'] = dados[presenca].sum(axis=1)
for i in range(len(dados['TP_PRESENCA_TT'])):
  if dados['TP_PRESENCA_TT'][i] != 4:
    dados['TP_PRESENCA_TT'][i] = 0
  else:
    dados['TP_PRESENCA_TT'][i]  = 1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
dados_nota_zero = dados.query('NU_NOTA_TOTAL ==0')
alunos_presentes_que_zeraram = dados_nota_zero.query('TP_PRESENCA_TT == 1')
alunos_ausentes_que_zeraram = dados_nota_zero.query('TP_PRESENCA_TT == 0')

# %%
print("Foram {} alunos presentes que tiraram zero e {} alunos que faltaram ao menos um dia que zeraram".format(len(alunos_presentes_que_zeraram),len(alunos_ausentes_que_zeraram)))
# Out:
# Foram 122 alunos presentes que tiraram zero e 29040 alunos que faltaram ao menos um dia que zeraram

# %% [markdown]
# Fim desafio 7

# %% [markdown]
# Desafio 8: Descobrir se quem é eliminado tira zero ou sera  NaN (Desafio 5 do dia 2)

# %%
dados[['TP_PRESENCA_CN','NU_NOTA_CN']].query('TP_PRESENCA_CN == 2').query('NU_NOTA_CN == 0')
# Out:
# Empty DataFrame
# Columns: [TP_PRESENCA_CN, NU_NOTA_CN]
# Index: []

# %%
dados[['TP_PRESENCA_CH','NU_NOTA_CH']].query('TP_PRESENCA_CH == 2').query('NU_NOTA_CH == 0')
# Out:
# Empty DataFrame
# Columns: [TP_PRESENCA_CH, NU_NOTA_CH]
# Index: []

# %%
dados[['TP_PRESENCA_LC','NU_NOTA_LC']].query('TP_PRESENCA_LC == 2').query('NU_NOTA_LC == 0')
# Out:
# Empty DataFrame
# Columns: [TP_PRESENCA_LC, NU_NOTA_LC]
# Index: []

# %%
dados[['TP_PRESENCA_MT','NU_NOTA_MT']].query('TP_PRESENCA_MT == 2').query('NU_NOTA_MT == 0')
# Out:
# Empty DataFrame
# Columns: [TP_PRESENCA_MT, NU_NOTA_MT]
# Index: []

# %% [markdown]
# Quem é eliminado fica com NaN

# %% [markdown]
# Fim desafio 8

# %%
dados_sem_nota_zero = dados.query('NU_NOTA_TOTAL !=0')
dados_sem_nota_zero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  ...  NU_NOTA_TOTAL TP_PRESENCA_TT
# 0  190001004661    2019  ...         2288.9              1
# 1  190001004674    2019  ...         1184.6              0
# 2  190001004722    2019  ...         2350.5              1
# 3  190001004735    2019  ...         2555.7              1
# 4  190001004776    2019  ...         2803.5              1
#
# [5 rows x 138 columns]

# %%
box_plot_padrao('Q006', 'NU_NOTA_TOTAL' , dados_sem_nota_zero, None)

# %%
box_plot_padrao('Q006', 'NU_NOTA_TOTAL' , dados_sem_nota_zero, 'IN_TREINEIRO')

# %% [markdown]
# Desafio 9: Verificar proporção dos participantes de rendas entre  treineiros  e não treineiros ( Desafio 6 do dia  2)

# %%
proporçao_treineiros_e_nao_treineiros = []
for i in renda_ordenada:
  proporçao_treineiros_e_nao_treineiros.append(dados['IN_TREINEIRO'][dados['Q006']==i].value_counts(normalize=True)[1])
df_proporcao = pd.DataFrame()
df_proporcao['Renda'] = renda_ordenada
df_proporcao['Proporcao'] = proporçao_treineiros_e_nao_treineiros

df_proporcao
# Out:
#    Renda  Proporcao
# 0      A   0.102055
# 1      B   0.095219
# 2      C   0.078757
# 3      D   0.095500
# 4      E   0.106803
# 5      F   0.151596
# 6      G   0.140428
# 7      H   0.200374
# 8      I   0.200732
# 9      J   0.224393
# 10     K   0.230769
# 11     L   0.278080
# 12     M   0.284404
# 13     N   0.284410
# 14     O   0.293142
# 15     P   0.335689
# 16     Q   0.362117

# %%
plt.figure(figsize=(12,10))
sns.set_theme(style="darkgrid")
sns.barplot(x='Renda',y='Proporcao', data=df_proporcao, palette='crest')
plt.show()

# %% [markdown]
# Fim Desafio 9

# %% [markdown]
# Desafio 10: Fazer o box plot usando o dado da Q025( acesso a internet) ( Desafio 7 do dia 2)

# %%
box_plot_padrao('Q025', 'NU_NOTA_TOTAL' , dados_sem_nota_zero, 'IN_TREINEIRO')

# %% [markdown]
# Fim desafio 10

# %% [markdown]
# #Aula 3

# %%
plt.figure(figsize=(10,8))
sns.histplot(dados_sem_nota_zero, x='NU_NOTA_TOTAL')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(dados_sem_nota_zero, x='NU_NOTA_MT')
sns.histplot(dados_sem_nota_zero, x='NU_NOTA_LC',color='g')
plt.show()

# %% [markdown]
# Desafio 11: Plotar as médias, medianas e  Moda das notas de LC e MT

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_nota_zero, x='NU_NOTA_MT')
plt.axhline((dados_sem_nota_zero['NU_NOTA_MT'].mean()),color='k',linestyle='--')

plt.axhline((dados_sem_nota_zero['NU_NOTA_MT'].median()),color='r',linestyle='--')

plt.axhline(dados_sem_nota_zero['NU_NOTA_MT'].mode()[0],color='g',linestyle='--')

plt.annotate('-- Media '+str(round(dados_sem_nota_zero['NU_NOTA_MT'].mean(),2)),color ='k',xy=(800,2800) )
plt.annotate('-- Mediana '+str(round(dados_sem_nota_zero['NU_NOTA_MT'].median(),2)),color ='r',xy=(800,2700) )
plt.annotate('-- Moda ' +str(round(dados_sem_nota_zero['NU_NOTA_MT'].mode()[0],2)),color ='g',xy=(800,2600) )
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_nota_zero, x='NU_NOTA_LC')

plt.axhline((dados_sem_nota_zero['NU_NOTA_LC'].mean()),color='k',linestyle='--')

plt.axhline((dados_sem_nota_zero['NU_NOTA_LC'].median()),color='r',linestyle='--')

plt.axhline(dados_sem_nota_zero['NU_NOTA_LC'].mode()[0],color='g',linestyle='--')

plt.annotate('-- Media '+str(round(dados_sem_nota_zero['NU_NOTA_LC'].mean(),2)),color ='k',xy=(600,2400) )
plt.annotate('-- Mediana '+str(round(dados_sem_nota_zero['NU_NOTA_LC'].median(),2)),color ='r',xy=(600,2300) )
plt.annotate('-- Moda ' +str(round(dados_sem_nota_zero['NU_NOTA_LC'].mode()[0],2)),color ='g',xy=(600,2200) )
plt.show()

# %% [markdown]
# Fim desafio 11

# %%
#Desafio 10 com histplot
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_nota_zero, x='NU_NOTA_TOTAL', hue='Q025', kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_nota_zero, x='NU_NOTA_TOTAL', hue='Q025', kde=True,stat='density')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_nota_zero, x='NU_NOTA_TOTAL', hue='Q025', kde=True,stat='probability')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_nota_zero, x='NU_NOTA_TOTAL', hue='Q025', kde=True,stat='density',cumulative=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=dados_sem_nota_zero, x='NU_NOTA_MT', y='NU_NOTA_LC')
plt.xlim((-50,1050))
plt.ylim((-50,1050))
plt.show()

# %%
sns.pairplot(dados_sem_nota_zero[provas])
plt.show()

# %%
correlacao = dados_sem_nota_zero[provas].corr()
correlacao
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# NU_NOTA_CN         1.000000    0.668979  ...         0.504740       0.785600
# NU_NOTA_CH         0.668979    1.000000  ...         0.528338       0.735534
# NU_NOTA_MT         0.649527    0.610332  ...         0.493046       0.790051
# NU_NOTA_LC         0.641624    0.744170  ...         0.535797       0.711686
# NU_NOTA_REDACAO    0.504740    0.528338  ...         1.000000       0.783647
# NU_NOTA_TOTAL      0.785600    0.735534  ...         0.783647       1.000000
#
# [6 rows x 6 columns]

# %%
sns.heatmap(correlacao, cmap='Blues',center=0, annot=True)

# %% [markdown]
# Desafio 12: Melhorar a matriz de correlação e analisar

# %%
import numpy as np
mascara=np.zeros_like(correlacao)
mascara[np.triu_indices_from(mascara)]=True
with sns.axes_style('white'):
  f,ax = plt.subplots(figsize=(10,8))
  ax = sns.heatmap(correlacao, cmap='Blues',center=0, annot=True, mask=mascara)

# %% [markdown]
# Fim desafio 12

# %% [markdown]
# Desafio 13: Filtrar notas pelo seu estado ou cidade e refazer as analises, verificando se sao semelhantes ao geral

# %%
dados_sem_nota_zero_rj = dados_sem_nota_zero.query('SG_UF_RESIDENCIA =="RJ"')
plt.figure(figsize=(10,8))
sns.histplot(dados_sem_nota_zero, x='NU_NOTA_TOTAL', color='g',kde=True)
sns.histplot(dados_sem_nota_zero_rj, x='NU_NOTA_TOTAL',kde=True)
plt.show()

# %%
sns.pairplot(dados_sem_nota_zero_rj[provas])
plt.show()

# %%
correlacao = dados_sem_nota_zero_rj[provas].corr()
mascara=np.zeros_like(correlacao)
mascara[np.triu_indices_from(mascara)]=True
with sns.axes_style('white'):
  f,ax = plt.subplots(figsize=(10,8))
  ax = sns.heatmap(correlacao, cmap='Blues',center=0, annot=True, mask=mascara)

# %%
diff = dados_sem_nota_zero_rj[provas].corr()-dados_sem_nota_zero[provas].corr()

mascara=np.zeros_like(diff)
mascara[np.triu_indices_from(mascara)]=True
with sns.axes_style('white'):
  f,ax = plt.subplots(figsize=(10,8))
  ax = sns.heatmap(diff, cmap='Blues',center=0, annot=True, mask=mascara)
plt.title('Diferença das correlaçoes de notas Do Brasil com as notas somente o RJ')
plt.show()

# %% [markdown]
# Desafio 14: Pensar na correlação sore as notas de MT e LC

# %% [markdown]
# Hipótese Sobre a correlação das notas e matemática e línguas, no ENEM a maior parte das questões exigem uma boa capacidade e interpretação do que esta sendo pedido, então uma pessoa para ir bem em matemática também teria que ser boa em interpretação aumentando assim as notas de LC. Porem o oposto não é valido pois uma pessoa boa em interpretação poderia saber exatamente o que uma questão de matemática pede porem lhe falta habilidades matemáticas para resolver o problema.

# %% [markdown]
# Fim desafio 14

# %% [markdown]
# #Aula 4

# %%
provas_entrada = ['NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_CN','NU_NOTA_REDACAO']
prova_saida = 'NU_NOTA_MT'

dados_sem_nota_zero = dados_sem_nota_zero[provas].dropna()

notas_entrada = dados_sem_nota_zero[provas_entrada]
notas_saida =dados_sem_nota_zero[prova_saida]

x = notas_entrada
y = notas_saida

SEED = 4321
from sklearn.model_selection import train_test_split
x_treino,x_teste,y_treino,y_teste = train_test_split(x,y,test_size = 0.25, random_state =SEED)

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state = SEED)
modelo.fit(x_treino, y_treino)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#           intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#           random_state=4321, tol=0.0001, verbose=0)

# %%
predicoes_matematica=modelo.predict(x_teste)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=predicoes_matematica,y=y_teste)
plt.xlim((-50,1050))
plt.ylim((-50,1050))
plt.show()

# %%
#100% de acerto
plt.figure(figsize=(10,10))
sns.scatterplot(x=y_teste,y=y_teste)
plt.xlim((-50,1050))
plt.ylim((-50,1050))
plt.show()

# %%
#Sccaterplot do erro
plt.figure(figsize=(10,10))
sns.scatterplot(x=y_teste,y=y_teste-predicoes_matematica)
plt.xlim((-500,1050))
plt.ylim((-500,1050))
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=y_teste,y=x_teste.mean(axis=1))
plt.xlim((-500,1050))
plt.ylim((-500,1050))
plt.show()

# %%
#metrica do modelo
resultados = pd.DataFrame()
resultados['Real'] = y_teste
resultados['Previsao'] = predicoes_matematica
resultados['Diferenca'] = resultados['Real']-resultados['Previsao']
resultados['Quadrado Diferenca'] = resultados['Diferenca']**2

# %%
resultados['Quadrado Diferenca'].mean()**(1/2)
# Out:
# 81.26755383435341

# %%
from sklearn.dummy import DummyRegressor

modelo_dummy = DummyRegressor()
modelo_dummy.fit(x_treino,y_treino)
dummy_predicoes = modelo_dummy.predict(x_teste)

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_teste, dummy_predicoes)
# Out:
# 12063.645588509502

# %%
mean_squared_error(y_teste, predicoes_matematica)
# Out:
# 6604.41530621957

# %% [markdown]
# Desafio 15 : Procurar outro modelo de ML para treinar e comparar com o da aula

# %%
from sklearn import linear_model

bayesian_model = linear_model.BayesianRidge()
bayesian_model.fit(x_treino, y_treino)

bayesian_model_predict = bayesian_model.predict(x_teste)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=bayesian_model_predict,y=y_teste)
plt.xlim((-50,1050))
plt.ylim((-50,1050))
plt.show()

plt.figure(figsize=(10,10))
sns.scatterplot(x=predicoes_matematica,y=y_teste, color='orange')
plt.xlim((-50,1050))
plt.ylim((-50,1050))
plt.show()

# %% [markdown]
# Fim desafio 15

# %% [markdown]
# Desafio 16: Alterar o metodo de regressão do Dummy

# %%
from sklearn.dummy import DummyRegressor

modelo_dummy = DummyRegressor(strategy="median")
modelo_dummy.fit(x_treino,y_treino)
dummy_predicoes = modelo_dummy.predict(x_teste)

mean_squared_error(y_teste, dummy_predicoes)
# Out:
# 12599.969971795981

# %%
modelo_dummy = DummyRegressor(strategy="quantile",quantile=0.585)
modelo_dummy.fit(x_treino,y_treino)
dummy_predicoes = modelo_dummy.predict(x_teste)

mean_squared_error(y_teste, dummy_predicoes)
# Out:
# 12088.156521720337

# %% [markdown]
# Fim desafio 16

# %% [markdown]
# Desafio 17: Utilizar outra metrica para avaliao o modelo de regressão

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_teste, predicoes_matematica)
# Out:
# 66.04555425503301

# %%
mean_absolute_error(y_teste, dummy_predicoes)
# Out:
# 91.32536416684677

# %%
from sklearn.metrics import max_error
max_error(y_teste, predicoes_matematica)
# Out:
# 453.50682298836375

# %%
max_error(y_teste, dummy_predicoes)
# Out:
# 529.9

# %% [markdown]
# Fim desafio 17

# %%
dados_sem_nota_zero_m = dados.query('NU_NOTA_TOTAL !=0')
dados_sem_nota_zero_m['NU_NOTA_TOTAL_MEDIA']=dados_sem_nota_zero_m['NU_NOTA_TOTAL']/5
fig = plt.figure(figsize=(16,12))
axis = fig.add_axes([0,0,1,1])


plt.title('Boxplot de nota total media por renda familiar', fontsize=14)
media_geral = medias_renda['Media Geral']
index=range(len(rendas_ticks))

axis.grid(True)
sns.boxplot(x="Q006", y='NU_NOTA_TOTAL_MEDIA', data=dados_sem_nota_zero_m, order=renda_ordenada)

axis.set_yticks([100,200,300,400,450,500,550,600,650,700,750,800,900])
axis.set_xticks(index)
axis.set_xticklabels(rendas_ticks)
plt.xticks(rotation=60)

#axis.axhline(max(medias_renda['Media Geral']),color='k',linestyle='--')
#axis.axhline(min(medias_renda['Media Geral']),color='k',linestyle='--')



plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #Aula 5

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state = SEED)
modelo.fit(x_treino, y_treino)
predicoes_matematica=modelo.predict(x_teste)

mean_squared_error(y_teste, predicoes_matematica)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 6604.41530621957

# %%
from sklearn.tree import DecisionTreeRegressor

x_treino,x_teste,y_treino,y_teste = train_test_split(x,y,test_size = 0.25) #random_state =SEED)

modelo_arvore = DecisionTreeRegressor(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
predicoes_matematica_arvore=modelo_arvore.predict(x_teste)

mean_squared_error(y_teste, predicoes_matematica_arvore)
# Out:
# 6039.78288228443

# %%
from sklearn.model_selection import cross_validate

modelo_arvore = DecisionTreeRegressor(max_depth = 2)
resultado = cross_validate(modelo_arvore,  x,y, cv=10, scoring='neg_mean_squared_error')
media = (resultado['test_score']*-1).mean()
desvio_padrao = (resultado['test_score']*-1).std()
lim_inferior = media - (2*desvio_padrao)
lim_superior = media + (2*desvio_padrao)

# %%
print(f'Intervalo de confiaça {lim_inferior} - {lim_superior}')
# Out:
# Intervalo de confiaça 6015.722549536811 - 7100.73277978073

# %% [markdown]
# Desafio 18: Pesquisar sobre intervalo ode confiança

# %%
def calcula_mse(resultado):
  media = (resultado['test_score']*-1).mean()
  desvio_padrao = (resultado['test_score']*-1).std()
  lim_inferior = media - (2*desvio_padrao)
  lim_superior = media + (2*desvio_padrao)
  print(f'Intervalo de confiaça {lim_inferior} - {lim_superior}')

# %%
calcula_mse(resultado)
# Out:
# Intervalo de confiaça 6015.722549536811 - 7100.73277978073

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold

partes=KFold(n_splits =10,  shuffle=True)

modelo_arvore = DecisionTreeRegressor(max_depth = 3)
resultado = cross_validate(modelo_arvore,  x,y, cv=10, scoring='neg_mean_squared_error')

# %%
calcula_mse(resultado)
# Out:
# Intervalo de confiaça 5533.563736266453 - 6594.205962103169

# %%
train_scores = []
test_scores = []
def regressor_arvore(nivel):
  SEED = 1232
  np.random.seed(SEED)
  partes=KFold(n_splits =10,  shuffle=True)

  modelo_arvore = DecisionTreeRegressor(max_depth = nivel)
  resultado = cross_validate(modelo_arvore,  x,y, cv=10, scoring='neg_mean_squared_error', return_train_score=True)
  
  print(f"Treino = {(resultado['train_score']*-1).mean()}")
  return calcula_mse(resultado)

# %%
for i in range(1,21):
  regressor_arvore(i)
# Out:
# Treino = 7844.682073218659
# Intervalo de confiaça 7222.427121471812 - 8505.310353474202
# Treino = 6527.876025936791
# Intervalo de confiaça 6015.722549536804 - 7100.732779780734
# Treino = 6022.186300615175
# Intervalo de confiaça 5533.563736266451 - 6594.205962103171
# Treino = 5759.961584344695
# Intervalo de confiaça 5285.870438260193 - 6370.5765466699495
# Treino = 5597.000627893682
# Intervalo de confiaça 5147.4943504110415 - 6228.355022036307
# Treino = 5469.042846377617
# Intervalo de confiaça 5045.492815920102 - 6146.482589104827
# Treino = 5368.559177408088
# Intervalo de confiaça 4992.909853359531 - 6082.042991245741
# Treino = 5276.26359241127
# Intervalo de confiaça 5013.0200536028515 - 6076.97159925712
# Treino = 5167.037078841886
# Intervalo de confiaça 5053.204348663982 - 6152.004455938338
# Treino = 5023.548703001954
# Intervalo de confiaça 5164.089856447474 - 6300.741066097089
# Treino = 4835.1922409649105
# Intervalo de confiaça 5371.606546946354 - 6517.53854739089
# Treino = 4599.420046760024
# Intervalo de confiaça 5616.501624218954 - 6789.349483615371
# Treino = 4323.229660887637
# Intervalo de confiaça 5937.203853638971 - 7090.054728979273
# Treino = 4011.188339462498
# Intervalo de confiaça 6266.912857025316 - 7443.273683818708
# Treino = 3673.4548675103915
# Intervalo de confiaça 6668.7399329329455 - 7842.821884786399
# Treino = 3317.3723013886556
# Intervalo de confiaça 7014.133113961285 - 8232.268008105733
# Treino = 2956.862980672298
# Intervalo de confiaça 7419.247528678066 - 8654.294938559155
# Treino = 2604.4405806771256
# Intervalo de confiaça 7784.2279206677495 - 9053.297675767279
# Treino = 2263.431861270091
# Intervalo de confiaça 8158.04098740122 - 9415.383353728923
# Treino = 1946.0448716489118
# Intervalo de confiaça 8523.791585627376 - 9796.042942410131

# %% [markdown]
# Desafio 19: Testar outros parametros da arvore de decisão

# %% [markdown]
# Desafio 20: Pocurar outras formas  de realizar os  ajustes dos parametros do SKlearn

# %%
SEED = 1232
np.random.seed(SEED)
partes=KFold(n_splits =10,  shuffle=True)

modelo_arvore = DecisionTreeRegressor(max_depth = 7,max_leaf_nodes=1000,min_samples_split=6,max_features='auto')
resultado = cross_validate(modelo_arvore,  x,y, cv=10,scoring='neg_mean_squared_error')

# %%
resultado['test_score'].mean()
# Out:
# -5535.868044219585

# %% [markdown]
# Fim desafios  19 e 20

# %% [markdown]
# Desafio 21: Pesquisar sobre underfit

# %% [markdown]
# https://machinelearningmastery.com/overfitting-and-underfitting-with-machine-learning-algorithms/

# %% [markdown]
# Desafio 22: Fazer um grafico de linha com o test_score e train_test
#
# ---

# %%
train_scores = []
test_scores = []
def regressor_arvore(nivel):
  SEED = 1232
  np.random.seed(SEED)
  partes=KFold(n_splits =10,  shuffle=True)

  modelo_arvore = DecisionTreeRegressor(max_depth = nivel)
  resultado = cross_validate(modelo_arvore,  x,y, cv=10, scoring='neg_mean_squared_error', return_train_score=True)
  
  return  (resultado['train_score']*-1).mean(),(resultado['test_score']*-1).mean()

# %%
for i in range(1,21):
  r=regressor_arvore(i)
  train_scores.append(r[0])
  test_scores.append(r[1])

# %%
plt.figure(figsize=(12,10))
sns.lineplot(y=train_scores,x=range(1,21))
sns.lineplot(y=test_scores,x=range(1,21),color='g')

plt.show()

# %% [markdown]
# FIm desafio 22
